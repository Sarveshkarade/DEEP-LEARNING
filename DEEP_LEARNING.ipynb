# %% [markdown]
# DEEP LEARNING PRACTICAL

# %%
#Q1:
import tensorflow as tf

print("TensorFlow version:", tf.__version__)
print("Num GPUs Available: ", len(tf.config.list_physical_devices('GPU')))
# Out:
# TensorFlow version: 2.18.0
# Num GPUs Available:  0

# %%
#Q2:
import tensorflow as tf

def add_numbers(x, y):
    return tf.add(x, y)
a = tf.constant(5)
b = tf.constant(3)
result = add_numbers(a, b)
print("Result:", result.numpy())
# Out:
# Result: 8

# %%
#Q3:
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import numpy as np
X = np.random.rand(100, 3)
y = np.random.rand(100, 1)
model = Sequential([
    Dense(8, activation='relu', input_shape=(3,)),
    Dense(1)
])
model.compile(optimizer='adam', loss='mse')
model.fit(X, y, epochs=10, batch_size=8)
test_input = np.array([[0.2, 0.4, 0.6]])
prediction = model.predict(test_input)
print("Prediction:", prediction)
# Out:
# Epoch 1/10
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - loss: 0.1617
# Epoch 2/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1585
# Epoch 3/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1301
# Epoch 4/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1295
# Epoch 5/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1266
# Epoch 6/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 5ms/step - loss: 0.1586
# Epoch 7/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1379
# Epoch 8/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1344
# Epoch 9/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 4ms/step - loss: 0.1518
# Epoch 10/10
# 13/13 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step - loss: 0.1279
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 62ms/step
# Prediction: [[0.42830485]]

# %%
#Q4:
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense
import matplotlib.pyplot as plt
import numpy as np
X = np.random.rand(200, 4)
y = np.random.randint(0, 2, size=(200, 1))
model = Sequential([
    Dense(8, activation='relu', input_shape=(4,)),
    Dense(1, activation='sigmoid')
])
model.compile(optimizer='adam', loss='binary_crossentropy', metrics=['accuracy'])
history = model.fit(X, y, epochs=20, batch_size=16, validation_split=0.2)
plt.plot(history.history['loss'], label='Train Loss')
plt.plot(history.history['val_loss'], label='Val Loss')
plt.title('Model Loss over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.grid(True)
plt.show()
plt.plot(history.history['accuracy'], label='Train Accuracy')
plt.plot(history.history['val_accuracy'], label='Val Accuracy')
plt.title('Model Accuracy over Epochs')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.grid(True)
plt.show()
# Out:
# Epoch 1/20
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/core/dense.py:87: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(activity_regularizer=activity_regularizer, **kwargs)
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 1s 45ms/step - accuracy: 0.5285 - loss: 0.7452 - val_accuracy: 0.5000 - val_loss: 0.8021
# Epoch 2/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 14ms/step - accuracy: 0.4577 - loss: 0.7859 - val_accuracy: 0.5000 - val_loss: 0.7886
# Epoch 3/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 16ms/step - accuracy: 0.5374 - loss: 0.7282 - val_accuracy: 0.5250 - val_loss: 0.7773
# Epoch 4/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 19ms/step - accuracy: 0.4549 - loss: 0.7610 - val_accuracy: 0.5250 - val_loss: 0.7667
# Epoch 5/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 15ms/step - accuracy: 0.5958 - loss: 0.6854 - val_accuracy: 0.5500 - val_loss: 0.7591
# Epoch 6/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5136 - loss: 0.7420 - val_accuracy: 0.5500 - val_loss: 0.7513
# Epoch 7/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 17ms/step - accuracy: 0.5277 - loss: 0.7082 - val_accuracy: 0.5500 - val_loss: 0.7450
# Epoch 8/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 18ms/step - accuracy: 0.5421 - loss: 0.6829 - val_accuracy: 0.5250 - val_loss: 0.7400
# Epoch 9/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4668 - loss: 0.7097 - val_accuracy: 0.5250 - val_loss: 0.7349
# Epoch 10/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5457 - loss: 0.6838 - val_accuracy: 0.5250 - val_loss: 0.7309
# Epoch 11/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4651 - loss: 0.7152 - val_accuracy: 0.5000 - val_loss: 0.7269
# Epoch 12/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 13ms/step - accuracy: 0.4913 - loss: 0.6952 - val_accuracy: 0.4750 - val_loss: 0.7239
# Epoch 13/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4133 - loss: 0.7191 - val_accuracy: 0.4750 - val_loss: 0.7208
# Epoch 14/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 10ms/step - accuracy: 0.4798 - loss: 0.7005 - val_accuracy: 0.4750 - val_loss: 0.7187
# Epoch 15/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4766 - loss: 0.6974 - val_accuracy: 0.5000 - val_loss: 0.7168
# Epoch 16/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5205 - loss: 0.6903 - val_accuracy: 0.5000 - val_loss: 0.7150
# Epoch 17/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 12ms/step - accuracy: 0.4878 - loss: 0.6890 - val_accuracy: 0.5000 - val_loss: 0.7134
# Epoch 18/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.4905 - loss: 0.6951 - val_accuracy: 0.4500 - val_loss: 0.7117
# Epoch 19/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5534 - loss: 0.6745 - val_accuracy: 0.4750 - val_loss: 0.7105
# Epoch 20/20
# 10/10 ━━━━━━━━━━━━━━━━━━━━ 0s 9ms/step - accuracy: 0.5116 - loss: 0.6894 - val_accuracy: 0.4500 - val_loss: 0.7093

# %%
#Q5:
import torch
print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
if torch.cuda.is_available():
    print("GPU Name:", torch.cuda.get_device_name(0))
    print("Total GPUs:", torch.cuda.device_count())
# Out:
# PyTorch version: 2.6.0+cu124
# CUDA available: False

# %%
#Q6:
import torch
import torch.nn as nn
import torch.optim as optim
X = torch.rand((100, 4))
y = torch.randint(0, 2, (100, 1))
class SimpleNN(nn.Module):
    def __init__(self):
        super(SimpleNN, self).__init__()
        self.fc1 = nn.Linear(4, 8)
        self.relu = nn.ReLU()
        self.fc2 = nn.Linear(8, 1)
        self.sigmoid = nn.Sigmoid()

    def forward(self, x):
        x = self.fc1(x)
        x = self.relu(x)
        x = self.fc2(x)
        x = self.sigmoid(x)
        return x
model = SimpleNN()
criterion = nn.BCELoss()
optimizer = optim.Adam(model.parameters(), lr=0.01)
epochs = 20
for epoch in range(epochs):
    model.train()
    outputs = model(X)
    loss = criterion(outputs, y.float())

    optimizer.zero_grad()
    loss.backward()
    optimizer.step()

    print(f"Epoch [{epoch+1}/{epochs}], Loss: {loss.item():.4f}")
# Out:
# Epoch [1/20], Loss: 0.6931
# Epoch [2/20], Loss: 0.6915
# Epoch [3/20], Loss: 0.6901
# Epoch [4/20], Loss: 0.6889
# Epoch [5/20], Loss: 0.6877
# Epoch [6/20], Loss: 0.6865
# Epoch [7/20], Loss: 0.6853
# Epoch [8/20], Loss: 0.6842
# Epoch [9/20], Loss: 0.6831
# Epoch [10/20], Loss: 0.6821
# Epoch [11/20], Loss: 0.6811
# Epoch [12/20], Loss: 0.6801
# Epoch [13/20], Loss: 0.6791
# Epoch [14/20], Loss: 0.6781
# Epoch [15/20], Loss: 0.6772
# Epoch [16/20], Loss: 0.6762
# Epoch [17/20], Loss: 0.6753
# Epoch [18/20], Loss: 0.6743
# Epoch [19/20], Loss: 0.6734
# Epoch [20/20], Loss: 0.6725

# %%
#Q7:
import torch.nn as nn

criterion = nn.MSELoss()

# %%
#Q8:
import torch

def custom_mae_loss(output, target):
    return torch.mean(torch.abs(output - target))

# %%
#Q9:

import tensorflow as tf
loaded_model = tf.keras.models.load_model('my_model')
